# %% [markdown]
# # Graded Challenge 4

# %% [markdown]
# ## Introduction
#
# Nama  : Fitri Octaviani
#
# Batch : HCK 006

# %% [markdown]
# # Import Library

# %%
# !pip install feature_engine

# %%
# import library yang dibutuhkan
import pandas as pd
import numpy  as np
import joblib

# %% [markdown]
# # Load Model

# %%
# load model
with open('kmeans_3.pkl','rb') as file_1:
    kmeans_3 = joblib.load(file_1)

# %% [markdown]
# # Data Loading

# %%
fitur = ['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX',
         'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE', 'cluster']


CUST_ID = [0.309036, 0.342970]
BALANCE = [0.803646, 0.729729]
BALANCE_FREQUENCY = [-0.028482, 0.485810]
PURCHASES = [-0.048801, 0.477393]
ONEOFF_PURCHASES = [0.680780, -0.984831]
INSTALLMENTS_PURCHASES = [-1.100724, -1.100724]
CASH_ADVANCE = [1.423045, -0.931192]
PURCHASES_FREQUENCY	= [-0.896683, 0.034117]
ONEOFF_PURCHASES_FREQUENCY = [-0.198615, -0.198616]
PURCHASES_INSTALLMENTS_FREQUENCY = [-0.970922, -0.970956]
CASH_ADVANCE_FREQUENCY = [2.041957, 1.041957]
CASH_ADVANCE_TRX = [-0.853380, -0.654555]
PURCHASES_TRX = [-1.396450, -1.396417]
CREDIT_LIMIT = [-1.546689, 0.253599]
PAYMENTS = [-0.973747, -0.973740]
MINIMUM_PAYMENTS = [-0.410285, 0.115075]
PRC_FULL_PAYMENT = [-0.576311, -0.174170]
TENURE = [-2.509449, 	-0.279550]
cluster = [1, 2]


data1 = {
    'CUST_ID':CUST_ID,
    'BALANCE':BALANCE,
    'BALANCE_FREQUENCY':BALANCE_FREQUENCY,
    'PURCHASES':PURCHASES,
    'ONEOFF_PURCHASES':ONEOFF_PURCHASES,
    'INSTALLMENTS_PURCHASES':INSTALLMENTS_PURCHASES,
    'CASH_ADVANCE':CASH_ADVANCE,
    'PURCHASES_FREQUENCY':PURCHASES_FREQUENCY,
    'ONEOFF_PURCHASES_FREQUENCY':ONEOFF_PURCHASES_FREQUENCY,
    'PURCHASES_INSTALLMENTS_FREQUENCY':PURCHASES_INSTALLMENTS_FREQUENCY,
    'CASH_ADVANCE_FREQUENCY':CASH_ADVANCE_FREQUENCY,
    'CASH_ADVANCE_TRX':CASH_ADVANCE_TRX,
    'PURCHASES_TRX':PURCHASES_TRX,
    'CREDIT_LIMIT':CREDIT_LIMIT,
    'PAYMENTS':PAYMENTS,
    'MINIMUM_PAYMENTS':MINIMUM_PAYMENTS,
    'PRC_FULL_PAYMENT':PRC_FULL_PAYMENT,
    'TENURE':TENURE,
    'cluster':cluster
}
df_infer = pd.DataFrame(data=data1,columns=fitur)

# %%
df_infer.head()
# Out:
#     CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  0.309036  0.803646          -0.028482  -0.048801          0.680780
# 1  0.342970  0.729729           0.485810   0.477393         -0.984831
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -1.100724      1.423045            -0.896683
# 1               -1.100724     -0.931192             0.034117
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.198615                         -0.970922
# 1                   -0.198616                         -0.970956
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                2.041957         -0.853380      -1.396450     -1.546689
# 1                1.041957         -0.654555      -1.396417      0.253599
#
#    PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE  cluster
# 0 -0.973747         -0.410285         -0.576311 -2.509449        1
# ...

# %% [markdown]
# # Model Inference

# %%
# predict result random forest model
pred_kmeans = kmeans_3.predict(df_infer)

# %%
# show data infer + prediction
df_infer['pred_cluster'] = pred_kmeans
df_infer
# Out:
#     CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  0.309036  0.803646          -0.028482  -0.048801          0.680780
# 1  0.342970  0.729729           0.485810   0.477393         -0.984831
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -1.100724      1.423045            -0.896683
# 1               -1.100724     -0.931192             0.034117
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.198615                         -0.970922
# 1                   -0.198616                         -0.970956
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                2.041957         -0.853380      -1.396450     -1.546689
# 1                1.041957         -0.654555      -1.396417      0.253599
#
#    PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE  cluster  \
# 0 -0.973747         -0.410285         -0.576311 -2.509449        1
# ...
